# %%
# load data from Google drive, set up for GPU if possible
import os
import sys
import warnings
from tensorflow import get_logger
get_logger().setLevel('ERROR')
warnings.filterwarnings("ignore", message="Setting the random state for TF")

import tensorflow
# Out:
# Mounted at /content/drive
# ['.config', 'drive', 'sample_data']
# 'Colab Notebooks'   img    MIRA     WSO1.gdoc
#  data		    logs   models  'WSO Usage.gdoc'

# %%
from google.colab import drive 
drive.mount('/content/drive', force_remount=True)

NotebookDir = "/content/drive/My Drive/Colab Notebooks"
DataDir = "/content/drive/My Drive/data"
ImgDir = "/content/drive/My Drive/img"
LogDir = "/contents/drive/My Drive/logs"
ModelDir = "/contents/drive/My Drive/models"
ModulelDir = "/content/drive/My Drive/Colab Notebooks/bby"
# install the bby module
os.chdir(ModulelDir)
# !pip install .
import bby

# set our device appropriately
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('No gpu')
else:
    print(gpu_info)
  
# note that mps device is available on M1 Mac hardware if properly installed
print("Num GPUs Available: ", len(tensorflow.config.list_physical_devices('GPU')))
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/drive/My Drive/Colab Notebooks/bby
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Created wheel for BBY: filename=BBY-0.4-py3-none-any.whl size=7295 sha256=0da65fd427285da0037369d25f650759218f79e85bee38a33fc11cec1309e741
#   Stored in directory: /tmp/pip-ephem-wheel-cache-biggl3il/wheels/ca/db/c0/53f76aec514218649c05e0de324fbde98d26f3870ba3fba435
# Successfully built BBY
# ...
#   Attempting uninstall: BBY
#     Found existing installation: BBY 0.4
#     Uninstalling BBY-0.4:
#       Successfully uninstalled BBY-0.4
# ...

# %%
def mycd(subdir):
  os.chdir(HomeDir)
  os.chdir(subdir)
  return
# Out:
# ['NPS_NATL_subset.csv',
#  'NPS_Natl_cleaned.csv',
#  'NPS_NATL_archive.xlsx',
#  'prom_list.csv',
#  'pass_list.csv',
#  'det_list.csv',
#  'saved_weights.pt']
